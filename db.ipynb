# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host = "127.0.0.1",
                               user ="root",
                               password ="Admin@123",
                               database = "red_bus",
                               )

cursor = conn.cursor()

# %%
create_table_query = """CREATE TABLE bus_info_NEW (
    id INT AUTO_INCREMENT PRIMARY KEY,
    state TEXT,
    route_name TEXT,
    route_link TEXT,
    busname TEXT,
    bustype TEXT,
    departing_time DATETIME,
    duration TEXT,
    reaching_time DATETIME,
    star_rating FLOAT,
    price DECIMAL(10, 2),
    seats_available INT
);
"""

cursor.execute(create_table_query)
conn.commit()

# %%
select_query = """SELECT * FROM bus_info_new ;"""

cursor.execute(select_query)
results = cursor.fetchall()

# %%
import pandas as pd
column_names = ['ID', 'state', 'route_name', 'route_link', 'busname', 'bustype', 'departing_time', 'duration', 'reaching_time', 'star_rating', 'price', 'seats_available']
df = pd.DataFrame(results, columns=column_names)

# %%
df
# Out:
#           ID state                route_name  \
# 0          1  KTCL               Pune to Goa
# 1          2  KTCL               Pune to Goa
# 2          3  KTCL               Pune to Goa
# 3          4  KTCL               Pune to Goa
# 4          5  KTCL               Pune to Goa
# ...      ...   ...                       ...
# 11780  11781  WBTC  Habra to Contai (Kanthi)
# 11781  11782  WBTC  Habra to Contai (Kanthi)
# 11782  11783  WBTC        Habra to Midnapore
# 11783  11784  WBTC        Habra to Midnapore
# 11784  11785  WBTC        Habra to Midnapore
#
#                                               route_link  \
# 0          https://www.redbus.in/bus-tickets/pune-to-goa
# 1          https://www.redbus.in/bus-tickets/pune-to-goa
# 2          https://www.redbus.in/bus-tickets/pune-to-goa
# 3          https://www.redbus.in/bus-tickets/pune-to-goa
# 4          https://www.redbus.in/bus-tickets/pune-to-goa
# ...                                                  ...
# 11780  https://www.redbus.in/bus-tickets/habra-to-con...
# 11781  https://www.redbus.in/bus-tickets/habra-to-con...
# 11782  https://www.redbus.in/bus-tickets/habra-to-mid...
# 11783  https://www.redbus.in/bus-tickets/habra-to-mid...
# 11784  https://www.redbus.in/bus-tickets/habra-to-mid...
#
#                                                  busname  \
# 0      Kadamba Transport Corporation Limited (KTCL) -...
# 1                                          Atmaram Gobus
# 2                                         Ashray Travels
# 3                                          Atmaram Gobus
# 4                                     Ashray Vip Yellows
# ...                                                  ...
# 11780  SBSTC-HABRA - DIGHA - VIA - NIBEDITA SETU - 04...
# 11781  SBSTC-HABRA - DIGHA - VIA - NIBEDITA SETU - 05...
# 11782              WBTC (CTC) Habra-Midnapur - 194|05:25
# 11783              WBTC (CTC) Habra-Midnapur - 194|05:55
# 11784  SBSTC-HABRA - MIDNAPUR - 06:20 (MID DEPOT) - 1398
#
#                              bustype      departing_time duration  \
# 0                  A/C Sleeper (2+1) 2024-07-12 19:15:00  10h 35m
# 1               VE A/C Sleeper (2+1) 2024-07-12 22:30:00  10h 15m
# 2      Bharat Benz A/C Sleeper (2+1) 2024-07-12 21:00:00  11h 30m
# 3               VE A/C Sleeper (2+1) 2024-07-12 21:00:00  10h 30m
# 4                  A/C Sleeper (2+1) 2024-07-12 20:30:00  11h 30m
# ...                              ...                 ...      ...
# 11780            Non AC Seater (2+3) 2024-07-17 04:00:00  20h 00m
# 11781            Non AC Seater (2+3) 2024-07-17 05:40:00  18h 20m
# 11782            Non AC Seater (2+3) 2024-07-17 05:25:00  04h 10m
# 11783            Non AC Seater (2+3) 2024-07-17 05:55:00  04h 20m
# 11784            Non AC Seater (2+3) 2024-07-17 06:20:00  17h 40m
#
#             reaching_time  star_rating   price  seats_available
# 0     2024-07-12 05:50:00          3.8  800.00               10
# 1     2024-07-12 08:45:00          4.6  606.00                7
# 2     2024-07-12 08:30:00          4.6  693.00                8
# 3     2024-07-12 07:30:00          4.4  555.00                9
# 4     2024-07-12 08:00:00          4.4  648.00               16
# ...                   ...          ...     ...              ...
# 11780 2024-07-17 00:00:00          4.4  159.00               37
# 11781 2024-07-17 00:00:00          4.4  159.00               26
# 11782 2024-07-17 09:35:00          4.1  138.00               39
# 11783 2024-07-17 10:15:00          4.1  138.00               27
# 11784 2024-07-17 00:00:00          4.6  143.00               27
#
# [11785 rows x 12 columns]

# %%
df.to_csv('redbus.csv')
